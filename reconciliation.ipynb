# %% [markdown]
# # Reconciliation Day

# %% [markdown]
# * Code for drop down menu reconciliation

# %%
# %matplotlib inline
import pandas as pd
import csv
import matplotlib.pyplot as plt
from collections import Counter
from pprint import pprint
from dateutil import parser

# %% [markdown]
# - Making a dictionary of lists, key is the subject value is the row

# %%
def read_clean_data(file_name):
    data = {}
    with open(file_name, 'r') as in_file:
        reader = csv.DictReader(in_file)
        headers = reader.fieldnames
        for row in reader:
            key = row['filename']
            #print(key)
            xscripts = data.get(key, [])
            xscripts.append(row)
            data[key] = xscripts
            #if reader.line_num >10: 
            #    break
        print(reader.line_num)
    return data, headers

# %%
data,headers = read_clean_data('BritHerbaraiDataset.StutterRemoved.csv')
#pprint(data)
print(len(data))
# Out:
# 6548
# 3150

# %%
def count_transcripts(data):
    return Counter([len(v) for k, v in data.items()])

# %%
cc = count_transcripts(data)
pprint(cc)
# Out:
# Counter({1: 1174, 2: 945, 3: 645, 4: 384, 6: 2})

# %% [markdown]
# - Function to get all the flags for the drop down reconciliations
# - count blanks for each subject and throw them out for the reconciliation write a flag out with # of blanks

# %%
FLAGS = ['all agree', 'Majority Rules','only a single transcript','more than 1 unique answer','all are blank']

def drop_down_reconciliation(col):
    flags={}
    for key, xscripts in data.items():
        counts = Counter([x[col] for x in xscripts if x[col] and x[col].lower() != 'placeholder'])
        if not len(counts):
            flags[key] = dict(flag=FLAGS[4], value='', top_count=0, blank_count=len(xscripts))
        elif len(counts) > 1:
            top = counts.most_common(1)[0]
            cc = Counter([v for k, v in counts.items()])
            ii = 0
            for v in counts.values():
                ii += v
            if cc[top[1]] == 1:
                flags[key] = dict(flag=FLAGS[1], value=top[0], top_count=top[1], blank_count=len(xscripts) - ii)
            else:
                flags[key] = dict(flag=FLAGS[3], value=[k for k,v in counts.items() if v == top[1]], 
                                    top_count=top[1], blank_count=len(xscripts) - ii)
        elif len(xscripts) == 1:
            top = counts.most_common(1)[0]
            flags[key] = dict(flag=FLAGS[2], value=top[0], top_count=top[1], blank_count=len(xscripts) -1)
        elif len(xscripts) > 1 and len(counts) == 1:
            top = counts.most_common(1)[0]
            flags[key] = dict(flag=FLAGS[0], value=top[0], top_count=top[1], blank_count=len(xscripts) - top[1])
        else:
            pprint(xscripts)
    return flags

# %%
def date_parser(value):
    parts = value.split('/')
    pprint(parts)
    try:
        flag = 'ok'
        dt = parser.parse(value, fuzzy=True)
    except ValueError:
        flag = 'error'
        dt = ''
    return dt.isoformat(), flag

# %%
pprint(date_parser(''))
pprint(date_parser('3/8/1922'))
pprint(date_parser('3/8/0000'))
# Out:
# ['']
# ('2016-05-04T00:00:00', 'ok')
# ['3', '8', '1922']
# ('1922-03-08T00:00:00', 'ok')
# ['3', '8', '0000']
# ('2000-03-08T00:00:00', 'ok')

# %% [markdown]
# - function to count the flags and print results

# %%
def count_result(flags):
    counts = Counter([f['flag'] for k, f in flags.items()])
    total = 0
    for f, c in counts.items():
        total += c
        print('{} = {}'.format(f, c))
    print('Total = {}'.format(total))

# %%
out_dict = {k: {} for k in data.keys() }

# %%
def add_reconciled_data(field_name, flags):
    for k, f in flags.items():
        out_dict[k][field_name] = f['value']
        out_dict[k][field_name +'_flags'] = f['flag']
        out_dict[k][field_name +'_frequency'] = f['top_count']
        out_dict[k][field_name +'_blanks'] = f['blank_count']

# %%
flags = drop_down_reconciliation('Country')
add_reconciled_data('Country', flags)
count_result(flags)
flags = drop_down_reconciliation('County')
add_reconciled_data('County', flags)
count_result(flags)
flags = drop_down_reconciliation('State')
add_reconciled_data('State', flags)
count_result(flags)
# Out:
# Majority Rules = 2
# all agree = 1969
# only a single transcript = 1104
# more than 1 unique answer = 1
# all are blank = 74
# Total = 3150
# Majority Rules = 20
# all agree = 1923
# only a single transcript = 1094
# more than 1 unique answer = 21
# all are blank = 92
# Total = 3150
# Majority Rules = 19
# all agree = 1939
# only a single transcript = 1105
# more than 1 unique answer = 9
# all are blank = 78
# Total = 3150

# %%
pprint(out_dict)
# Out:
# {'BRIT118000': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118001': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118003': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118004': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118005': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118006': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118007': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118008': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118009': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118010': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118011': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118012': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118013': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118014': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118015': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118017': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118018': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118019': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118021': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118022': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118023': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118024': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118025': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118027': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118029': {'Country': 'United States',
#                 'Country_blanks': 3,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 1},
#  'BRIT118030': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118031': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT118032': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118035': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118036': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118037': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118038': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118039': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118040': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118043': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118044': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118045': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118046': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118049': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118051': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118054': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118059': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118061': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118063': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118065': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118066': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118067': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118068': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118069': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118072': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118073': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118074': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118075': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118076': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118077': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118078': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118080': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 1},
#  'BRIT118082': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118083': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118085': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118086': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118087': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118088': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118089': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118090': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118091': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118092': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118093': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118094': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118095': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118096': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118097': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT118098': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 1},
#  'BRIT118100': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118101': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118102': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118103': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118104': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118105': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118106': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118107': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118108': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT118110': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118111': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118112': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118113': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118114': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118115': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118116': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118117': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118118': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118119': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118120': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118121': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118122': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118123': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118125': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118126': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118127': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118129': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118130': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118132': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118133': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118134': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118136': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118137': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118138': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118139': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118140': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 1},
#  'BRIT118141': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118142': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118145': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118149': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118150': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118151': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118152': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118153': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118154': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118155': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118158': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118159': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118160': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118161': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118162': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118163': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118164': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118165': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118166': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118168': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118169': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT118170': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118171': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118172': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118173': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118176': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT118178': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 1},
#  'BRIT118179': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118180': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118181': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118182': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118183': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118184': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118185': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118186': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118188': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118189': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118190': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 1},
#  'BRIT118191': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118193': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118194': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118195': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118196': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118197': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT118198': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118199': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118201': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118203': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118204': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118207': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118208': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118210': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118212': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118214': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118215': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118216': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118220': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118222': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118223': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118225': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118227': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118228': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118230': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118232': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118233': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118234': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118235': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118236': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118238': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118239': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118240': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118241': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118242': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118243': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118245': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118246': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118248': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118249': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118250': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118251': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118252': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118253': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118255': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118256': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118257': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118258': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT118259': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118260': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118261': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118262': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT118263': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118265': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118266': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118267': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118268': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118269': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118270': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118271': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118272': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118273': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118275': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118276': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118277': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118280': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT118282': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118283': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118284': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 1},
#  'BRIT118286': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118288': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118289': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118290': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118291': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118292': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118294': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118295': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118299': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118301': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118302': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118303': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118304': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118305': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118307': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118309': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118310': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118311': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118312': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118313': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118314': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118316': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118317': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118318': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118319': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118320': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118321': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118322': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118323': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118325': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118326': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118327': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118328': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118329': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118330': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118331': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118332': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118334': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118335': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118336': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118337': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118338': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118339': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118340': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118341': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118342': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118343': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118345': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118346': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118347': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118348': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT118350': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118351': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118353': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT118354': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118357': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118359': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT118360': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118362': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118365': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT118368': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT118369': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
# ...
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127875': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127876': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127877': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127879': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127880': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127881': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127882': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT127883': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127884': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127885': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127886': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127887': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127889': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127890': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127891': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127892': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127893': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127896': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127897': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT127898': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 1},
#  'BRIT127900': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127901': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 4},
#  'BRIT127902': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127903': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127904': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127905': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 1},
#  'BRIT127906': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127907': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127908': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127909': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127910': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127911': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127912': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127914': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127915': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127916': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127917': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127918': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127920': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127921': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127922': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127925': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127926': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127927': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127928': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127929': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127930': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127932': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127933': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127934': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127935': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127936': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127937': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127938': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127939': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127940': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127941': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127942': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127943': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127944': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127945': {'Country': 'United States',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 1},
#  'BRIT127946': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127947': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127949': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127950': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127951': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127953': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127955': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127956': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127957': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127958': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127961': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127967': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT127968': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127971': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127972': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127973': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127974': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127977': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127978': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127979': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127980': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127982': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127985': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127986': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127987': {'Country': '',
#                 'Country_blanks': 1,
#                 'Country_flag': 'all are blank',
#                 'Country_frequency': 0},
#  'BRIT127989': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127990': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 2},
#  'BRIT127992': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127996': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1},
#  'BRIT127998': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'all agree',
#                 'Country_frequency': 3},
#  'BRIT127999': {'Country': 'United States',
#                 'Country_blanks': 0,
#                 'Country_flag': 'only a single transcript',
#                 'Country_frequency': 1}}

# %%
flags = drop_down_reconciliation('County')
results = count_result(flags)
pprint(results)
# Out:
# Majority Rules = 20
# all agree = 1923
# only a single transcript = 1094
# more than 1 unique answer = 21
# all are blank = 92
# Total = 3150
# None

# %%
def write_reconciled_csv(out_dict, file_name):
    headers = list(list(out_dict.values())[0].keys())
    with open(file_name, 'w') as out_file:
        writer = csv.DictWriter(out_file,headers)
        writer.writeheader()
        for subject_id, row in out_dict.items():
            row['subject_id'] = subject_id
            writer.writerow(row)
    pprint(headers)

# %%
write_reconciled_csv(out_dict, 'Brit_Reconciled.csv')
# Out:
# ['State_frequency',
#  'Country_flags',
#  'Country_frequency',
#  'Country_blanks',
#  'County_frequency',
#  'State_flags',
#  'County_blanks',
#  'State_blanks',
#  'subject_id',
#  'Country',
#  'County_flags',
#  'County',
#  'State',
#  'Country_flag']
